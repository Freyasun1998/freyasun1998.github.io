# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# read data
hotel = pd.read_csv('hotel.csv')
hotel.head()
# Out:
#        Date        Open        High         Low       Close   Adj Close  \
# 0   12/7/20  146.000000  165.000000  135.100006  139.250000  139.250000
# 1  12/14/20  135.000000  159.000000  121.500000  157.300003  157.300003
# 2  12/21/20  155.309998  174.970001  145.110001  154.839996  154.839996
# 3  12/28/20  158.600006  163.639999  143.119995  146.800003  146.800003
# 4    1/4/21  150.990005  155.539993  137.000000  149.770004  149.770004
#
#      Volume Company
# 0  97428300    ABNB
# 1  79299000    ABNB
# 2  37134600    ABNB
# 3  17889700    ABNB
# 4  25696400    ABNB

# %%
sns.lineplot(data=hotel, x="Date", y="Open", hue="Company")
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Open'>

# %%
sns.lineplot(data=hotel, x="Date", y="High", hue="Company")
# Out:
# <AxesSubplot:xlabel='Date', ylabel='High'>

# %%
sns.lineplot(data=hotel, x="Date", y="Low", hue="Company")
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Low'>

# %%
sns.lineplot(data=hotel, x="Date", y="Close", hue="Company")
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Close'>

# %%
sns.lineplot(data=hotel, x="Date", y="Volume", hue="Company")
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Volume'>

# %%
sns.lineplot(data=hotel, x="Date", y="Adj Close", hue="Company")
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Adj Close'>

# %%
ABNB = hotel.query("Company == 'ABNB'")
sns.lineplot(data=ABNB,x="Date",y="Open",color="blue")
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Open'>

# %%
EXPE = hotel.query("Company == 'EXPE'")
sns.lineplot(data=EXPE,x="Date",y="Open",color="green")
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Open'>

# %%
sns.lineplot(data=ABNB,x="Date",y="High",color="blue")
# Out:
# <AxesSubplot:xlabel='Date', ylabel='High'>

# %%
sns.lineplot(data=EXPE,x="Date",y="High",color="green")
# Out:
# <AxesSubplot:xlabel='Date', ylabel='High'>

# %%
sns.lineplot(data=ABNB,x="Date",y="Low",color="blue")
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Low'>

# %%
sns.lineplot(data=EXPE,x="Date",y="Low",color="green")
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Low'>

# %%
sns.lineplot(data=ABNB,x="Date",y="Close",color="blue")
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Close'>

# %%
sns.lineplot(data=EXPE,x="Date",y="Close",color="green")
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Close'>

# %%
sns.lineplot(data=ABNB,x="Date",y="Adj Close",color="blue")
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Adj Close'>

# %%
sns.lineplot(data=EXPE,x="Date",y="Adj Close",color="green")
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Adj Close'>

# %%
BKNG = hotel.query("Company == 'BKNG'")
sns.lineplot(data=BKNG,x="Date",y="Volume",color="orange")
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Volume'>
